# %%
import datetime
import xlsxwriter
import chardet
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading https://files.pythonhosted.org/packages/82/50/780122e4790328c195475d6e49a07fb69593508355dfee98bfb22686d9e8/XlsxWriter-1.2.1-py2.py3-none-any.whl (140kB)
#      |████████████████████████████████| 143kB 6.5MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-1.2.1

# %%
crops = pd.read_excel('Crops_dataset.xlsx')
rainfall = pd.read_excel('Rainfall_dataset.xlsx')
region = pd.read_excel('Region_dataset.xlsx')

# %%
merge1 = pd.merge(crops, region, how='inner', on=['Crops'])
merge2 = pd.merge(merge1, rainfall, how='inner', on=['Region'])

# %%
merge2.drop(['Unnamed: 4','Unnamed: 1_x','Unnamed: 1_y','Rainfall'],axis=1)
# Out:
#            Crops  water need  temp(in C)  ...    Oct    Nov   Dec
# 0           Rice       125.0        21.0  ...    6.9    2.0   3.0
# 1          Wheat        50.0        18.5  ...    6.9    2.0   3.0
# 2         Lentil        37.5        20.0  ...    6.9    2.0   3.0
# 3      Sugarcane       120.0        27.5  ...    6.9    2.0   3.0
# 4           Rice       125.0        21.0  ...   10.4    0.0   0.0
# 5            Tea       175.0        25.0  ...   10.4    0.0   0.0
# 6           Jute       200.0        30.0  ...   10.4    0.0   0.0
# 7       Turmeric       200.0        25.0  ...   10.4    0.0   0.0
# 8           Rice       125.0        21.0  ...    9.0    0.8   0.7
# 9          Wheat        50.0        18.5  ...    9.0    0.8   0.7
# 10      Oilseeds        40.0        23.5  ...    9.0    0.8   0.7
# 11     Sugarcane       120.0        27.5  ...    9.0    0.8   0.7
# 12         Wheat        50.0        18.5  ...   48.3   16.2   0.1
# 13         Maize        90.0        21.0  ...   48.3   16.2   0.1
# 14        Pulses        42.5        23.5  ...   48.3   16.2   0.1
# 15        Lentil        37.5        20.0  ...   48.3   16.2   0.1
# 16        Cotton        85.0        22.5  ...   48.3   16.2   0.1
# 17          Jute       200.0        30.0  ...   48.3   16.2   0.1
# 18         Maize        90.0        21.0  ...  106.1  138.1   4.4
# 19       Millets        50.0        27.5  ...  106.1  138.1   4.4
# 20        Cotton        85.0        22.5  ...  106.1  138.1   4.4
# 21         Cocoa       175.0        27.0  ...  106.1  138.1   4.4
# 22       Coconut       175.0        27.0  ...  106.1  138.1   4.4
# 23       Millets        50.0        27.5  ...  308.1  223.6  79.4
# 24         Cocoa       175.0        27.0  ...  308.1  223.6  79.4
# 25        Rubber       200.0        27.0  ...  308.1  223.6  79.4
# 26       Coconut       175.0        27.0  ...  308.1  223.6  79.4
# 27  Black Pepper       250.0        26.0  ...  308.1  223.6  79.4
# 28      Oilseeds        40.0        23.5  ...    2.2    0.3   0.0
# 29     Groundnut        63.5        25.0  ...    2.2    0.3   0.0
# 30        Cotton        85.0        22.5  ...    2.2    0.3   0.0
# 31           Tea       175.0        25.0  ...   62.6   14.0  15.2
# 32          Jute       200.0        30.0  ...   62.6   14.0  15.2
# 33      Turmeric       200.0        25.0  ...   62.6   14.0  15.2
#
# [34 rows x 28 columns]

# %%
writer = pd.ExcelWriter("train_data.xlsx" , engine='xlsxwriter')
merge2.to_excel(writer, sheet_name='Sheet1')
writer.save()
